# %% [markdown]
# # B2. Методы группировки данных

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\kozhevnikovams\Downloads\data_sf.csv')
small_df = df[df.columns[1:8]].head(25)
small_df
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %% [markdown]
# Считаю, сколько раз каждая из национальностей встречается в серии Nationality

# %%
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Argentina    3
# Uruguay      3
# Germany      3
# Belgium      3
# France       2
# Slovenia     1
# Portugal     1
# Italy        1
# England      1
# Croatia      1
# Brazil       1
# Poland       1
# Name: Nationality, dtype: int64

# %%
s.index
# Out:
# Index(['Spain', 'Argentina', 'Uruguay', 'Germany', 'Belgium', 'France',
#        'Slovenia', 'Portugal', 'Italy', 'England', 'Croatia', 'Brazil',
#        'Poland'],
#       dtype='object')

# %%
s.index[0]
# Out:
# 'Spain'

# %% [markdown]
# Количество национальностей, которые встречаются в датафрейме small_df

# %%
len(s.index)
# Out:
# 13

# %% [markdown]
# Количество футболистов в small_df, которые относятся к немцам

# %%
s['Germany']
# Out:
# 3

# %% [markdown]
# Сборные, в которых больше 1 футболиста

# %%
s.loc[s > 1]
# Out:
# Spain        4
# Argentina    3
# Uruguay      3
# Germany      3
# Belgium      3
# France       2
# Name: Nationality, dtype: int64

# %% [markdown]
# Количество футболистов в процентах от общего числа в датасете

# %%
s = small_df['Nationality'].value_counts(normalize=True)
display(s)
# Out:
# Spain        0.16
# Argentina    0.12
# Uruguay      0.12
# Germany      0.12
# Belgium      0.12
# France       0.08
# Slovenia     0.04
# Portugal     0.04
# Italy        0.04
# England      0.04
# Croatia      0.04
# Brazil       0.04
# Poland       0.04
# Name: Nationality, dtype: float64

# %% [markdown]
# Количество футболистов внутри каждой возрастной группы

# %%
s = small_df['Age'].value_counts()
display(s)
# Out:
# 27    5
# 32    5
# 31    3
# 26    3
# 29    2
# 24    2
# 33    2
# 30    1
# 28    1
# 25    1
# Name: Age, dtype: int64

# %% [markdown]
# Группировка футболистов по их заработной плате с разделением на 4 промежутка

# %%
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %% [markdown]
# Футболисты с самой высокой зарплатой

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %% [markdown]
# Как называется футбольный клуб, представленный наименьшим количеством игроков в датасете?

# %%
f = df['Club'].value_counts()
display(f)
# Out:
# V-Varen Nagasaki     30
# Shonan Bellmare      30
# Vissel Kobe          29
# Padova               29
# FC Emmen             29
#                      ..
# FC Metz               8
# Dinamo Zagreb         7
# GD Chaves             7
# Vitória Guimarães     7
# Atlético Mineiro      6
# Name: Club, Length: 650, dtype: int64

# %% [markdown]
# Сколько футбольных клубов представлено в датасете

# %%
len(f.index)
# Out:
# 650

# %% [markdown]
# Данные об игроках каких позиций занимают менее 1% датасета

# %%
f = df['Position'].value_counts(normalize=True)
display(f)
# Out:
# GK     0.127239
# ST     0.117237
# CB     0.108785
# CM     0.082732
# LB     0.077692
# RB     0.073505
# RM     0.059394
# LM     0.056447
# CDM    0.053578
# CAM    0.049081
# RCB    0.032411
# LCB    0.031713
# LW     0.018764
# RCM    0.018609
# RW     0.018376
# LCM    0.018066
# LDM    0.011476
# RDM    0.010700
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# LAM    0.000465
# RF     0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %% [markdown]
# Группировка игроков по зарплате

# %%
small_df = df[df.columns[0:7]].head(25)
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %% [markdown]
# В каких пределах находятся худшие 20% показателей точности ударов ногой (FKAccuracy)?

# %%
d = df['FKAccuracy'].value_counts(bins=5)
display(d)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %% [markdown]
# Подсчитать количество уникальных национальностей

# %%
s = small_df['Nationality'].value_counts()
print(s.index)
print(len(s.index))
# Out:
# Index(['Spain', 'Argentina', 'Uruguay', 'Germany', 'Belgium', 'France',
#        'Slovenia', 'Portugal', 'Italy', 'England', 'Croatia', 'Brazil',
#        'Poland'],
#       dtype='object')
# 13

# %% [markdown]
# То же самое с функцией unique

# %%
small_df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy'], dtype=object)

# %%
len(small_df['Nationality'].unique())
# Out:
# 13

# %%
small_df['Nationality'].nunique()
# Out:
# 13

# %%
df['Position'].nunique()
# Out:
# 27

# %% [markdown]
# Количество видов позиций (Position), которые занимают игроки, представленные в датасете:

# %%
len(df['Position'].unique())
# Out:
# 27

# %%
len(df['Position'].value_counts())
# Out:
# 27

# %% [markdown]
# Преобразование серии value_counts в датафрейм

# %%
s = small_df['Nationality'].value_counts()
s_df = s.reset_index()

display(s_df)
# Out:
#         index  Nationality
# 0       Spain            4
# 1   Argentina            3
# 2     Uruguay            3
# 3     Germany            3
# 4     Belgium            3
# 5      France            2
# 6    Slovenia            1
# 7    Portugal            1
# 8       Italy            1
# 9     England            1
# 10    Croatia            1
# 11     Brazil            1
# 12     Poland            1

# %% [markdown]
# Переименовать столбцы получившегося датафрейма

# %%
s_df.columns = ['Nationality','Players Count']

display(s_df)
# Out:
#    Nationality  Players Count
# 0        Spain              4
# 1    Argentina              3
# 2      Uruguay              3
# 3      Germany              3
# 4      Belgium              3
# 5       France              2
# 6     Slovenia              1
# 7     Portugal              1
# 8        Italy              1
# 9      England              1
# 10     Croatia              1
# 11      Brazil              1
# 12      Poland              1

# %% [markdown]
# У какого процента испанских специалистов (Nationality = 'Spain') зарплата (Wage) находится в пределах 25% минимума от наблюдаемого уровня зарплат?

# %%
d = df[df.Nationality == 'Spain']['Wage'].value_counts(bins=4, normalize=True)
display(d)
# Out:
# (620.999, 95750.0]      0.970194
# (95750.0, 190500.0]     0.016393
# (190500.0, 285250.0]    0.008942
# (285250.0, 380000.0]    0.004471
# Name: Wage, dtype: float64

# %% [markdown]
# Количество уникальных сборных (Nationality), к которым относятся футболисты, выступающие за клуб (Club) "Manchester United".

# %%
d = df[df.Club == 'Manchester United']['Nationality'].nunique()
display(d)
# Out:
# 13

# %% [markdown]
# С помощью функции unique определите двух футболистов из Бразилии (Nationality = 'Brazil'), выступающих за клуб (Club) 'Juventus'. Перечислите их имена (Name, как в датафрейме) через запятую в алфавитном порядке.

# %%
d = df[(df.Club == 'Juventus')&(df.Nationality == 'Brazil')]['Name'].unique()
display(d)
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %% [markdown]
# Какой клуб (Club) насчитывает большее количество футболистов возрастом (Age) старше 35 лет

# %%
d = df[df.Age > 35]
f = d['Club'].value_counts()
display(f)
# Out:
# Club Atlético Huracán         4
# Hokkaido Consadole Sapporo    4
# San Martín de San Juan        3
# Hammarby IF                   3
# Nagoya Grampus                3
#                              ..
# Villarreal CF                 1
# New York City FC              1
# Torino                        1
# Sligo Rovers                  1
# CD O'Higgins                  1
# Name: Club, Length: 212, dtype: int64

# %% [markdown]
# С помощью функции value_counts с параметром bins разбейте всех футболистов сборной (Nationality) Аргентины ('Argentina') на 4 равные группы. Укажите, сколько футболистов в возрасте от 34.75 до 41 года в сборной Аргентины.

# %%
d = df[df.Nationality == 'Argentina']['Age'].value_counts(bins=4)
display(d)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %% [markdown]
# Сколько процентов футболистов из Испании (Nationality = 'Spain') имеют возраст (Age) 21 год? Введите с точностью до 2 знаков после запятой без указания знака % (например, 12.35).

# %%
d = df[df.Nationality == 'Spain']
f = d['Age'].value_counts(normalize=True)
display(f)
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 29    0.047690
# 19    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 39    0.002981
# 16    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %% [markdown]
# # Группировка данных

# %% [markdown]
# Передать на вход колонку, по которой будет осуществляться группировка

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\kozhevnikovams\Downloads\data_sf.csv')
df.groupby(['Club'])

# %%
grouped_df = df.groupby(['Club']).sum()

display(grouped_df)
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %% [markdown]
# Сумма зарплат по клубам

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum()
display(grouped_df)
# Out:
# Club
#  SSV Jahn Regensburg      90000
# 1. FC Heidenheim 1846     76000
# 1. FC Kaiserslautern      33000
# 1. FC Köln                92000
# 1. FC Magdeburg           84000
#                           ...
# Zagłębie Sosnowiec        27000
# Çaykur Rizespor          118000
# Örebro SK                 36000
# Östersunds FK             39000
# Śląsk Wrocław             50000
# Name: Wage, Length: 650, dtype: int64

# %% [markdown]
# В каком клубе самая высокая зарплата?

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.head(5))
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
# Name: Wage, dtype: int64

# %% [markdown]
# Отметьте позиции (Position), по которым общая сумма зарплат (Wage) игроков превышает 5 млн евро в год.

# %%
grouped_df = df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.head(10))
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# CDM     4921000
# Name: Wage, dtype: int64

# %% [markdown]
#  Сгруппировать игроков по национальностям (Nationality) и посчитать среднюю зарплату, средний возраст и среднюю силу удара

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %% [markdown]
# Отсортировать по убыванию усредненной зарплаты

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %% [markdown]
# Подробнее о стране с самой высокой зарплатой

# %%
df.loc[df['Nationality'] == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]
# Out:
#             Name         Club    Wage  Age  ShotPower
# 291      Mariano  Real Madrid  140000   24         85
# 6279  L. Quezada   Córdoba CF    2000   22         66

# %% [markdown]
# Посчитайте среднюю зарплату (Wage) и цену (Value) игроков разных позиций (Position). Представители какой позиции имеют самую высокую среднюю цену?

# %%
df.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False).head(10)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06

# %% [markdown]
# Посчитайте среднюю (mean) и медианную (median) зарплату (Wage) футболистов из разных клубов (Club). В скольких клубах средняя и медианная зарплаты совпадают?
#
# Подсказка: чтобы в процессе группировки применить к данным одновременно две агрегирующие функции, необходимо указать их как аргументы метода agg:
#
# df.groupby(столбец_для_группировки)[столбцы_для_отображения].agg(['функция_1', 'функция_2'])

# %%
a = df.groupby(['Club'])['Wage'].agg(['mean', 'median'])
b = a[a['mean'] == a['median']].count()
display(b)
# Out:
# mean      52
# median    52
# dtype: int64

# %% [markdown]
# Продолжаем работать с клубами, в которых средняя зарплата совпадает с медианной. Каков максимальный размер средней зарплаты в этой группе клубов?

# %%
a = df.groupby(['Club'])['Wage'].agg(['mean', 'median'])
b = a[a['mean'] == a['median']]
display(b)
# Out:
#                            mean  median
# Club
# 1. FC Magdeburg          4000.0    4000
# AEK Athens               1000.0    1000
# AJ Auxerre               2000.0    2000
# Benevento                2000.0    2000
# Bohemian FC              1000.0    1000
# Boyacá Chicó FC          1000.0    1000
# Bray Wanderers           1000.0    1000
# Brøndby IF               6000.0    6000
# CD Feirense              4000.0    4000
# CD Tondela               2000.0    2000
# Cork City                1000.0    1000
# Cruzeiro                13000.0   13000
# Deportivo Pasto          1000.0    1000
# Dinamo Zagreb            1000.0    1000
# Dundalk                  1000.0    1000
# Dynamo Kyiv              1000.0    1000
# Envigado FC              1000.0    1000
# FC Energie Cottbus       1000.0    1000
# FC Metz                  1500.0    1500
# Grimsby Town             2000.0    2000
# Göztepe SK               7000.0    7000
# HJK Helsinki             1000.0    1000
# ...

# %% [markdown]
# С помощью функции groupby посчитайте сумму зарплат (Wage) футболистов клуба (Club) "Chelsea".

# %%
d = df[df.Club == 'Chelsea']
n = d.groupby(['Club'])['Wage'].sum()
display(n)
# Out:
# Club
# Chelsea    2035000
# Name: Wage, dtype: int64

# %% [markdown]
# Определите максимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") в возрасте 20 лет.

# %%
d = df[df.Nationality == 'Argentina']
n = d.groupby(['Age'])['Wage'].min()
display(n)
# Out:
# Age
# 16    1000
# 17    1000
# 18    1000
# 19    1000
# 20    1000
# 21    1000
# 22    1000
# 23    1000
# 24    1000
# 25    1000
# 26    1000
# 27    1000
# 28    2000
# 29    1000
# 30    1000
# 31    1000
# 32    1000
# 33    1000
# 34    1000
# 35    1000
# 36    1000
# 37    2000
# 38    2000
# 39    2000
# 40    2000
# 41    1000
# Name: Wage, dtype: int64

# %% [markdown]
# Определите максимальную силу (Strength) и баланс (Balance) среди игроков клуба (Club) "FC Barcelona" из Аргентины ("Argentina"). Ответ введите через точку с запятой без пробела.

# %%
d = df[(df.Nationality == 'Argentina')&(df.Club == 'FC Barcelona')]
n = d.groupby(['Strength'])['Balance'].max()
display(n)
# Out:
# Strength
# 59    95
# Name: Balance, dtype: int64

# %% [markdown]
# # Сводные таблицы

# %% [markdown]
# В параметр values мы передаем ту колонку, по которой нам нужно строить сводные данные, применяя агрегирующую функцию сумма.
#
# В параметр index передадим ту колонку, данные которой будут представлены строками сводной таблицы.
#
# В параметр columns передаем колонку, значения которой будут в столбцах.
#
# В параметр aggfunc передаем агрегирующую функцию.
#
# Для того, чтобы добавить столбец и строку с итоговыми значениями, нужно добавить параметр margins=True:

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True)
display(pivot)
# Out:
#                            Wage                                           \
# Club               FC Barcelona   Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0   205000.0          206000.0         NaN
# Belgium                110000.0        NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN   180000.0               NaN         NaN
# Brazil                 465000.0   335000.0           91000.0    570000.0
# Chile                  205000.0        NaN          215000.0         NaN
# Costa Rica                  NaN        NaN               NaN    195000.0
# Croatia                260000.0   160000.0               NaN    420000.0
# Dominican Republic          NaN        NaN               NaN    140000.0
# Ecuador                     NaN        NaN          120000.0         NaN
# England                     NaN        NaN          478000.0         NaN
# France                 495000.0   145000.0          375000.0    459000.0
# ...

# %% [markdown]
# Сводная таблица, показывающая максимальные зарплаты игроков на разных позициях, играющих за разные клубы

# %%
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')
display(pivot)
# Out:
#                            Wage                                           \
# Club               FC Barcelona   Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0   205000.0          206000.0         NaN
# Belgium                110000.0        NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN   180000.0               NaN         NaN
# Brazil                 465000.0   335000.0           91000.0    570000.0
# Chile                  205000.0        NaN          215000.0         NaN
# Costa Rica                  NaN        NaN               NaN    195000.0
# Croatia                260000.0   160000.0               NaN    420000.0
# Dominican Republic          NaN        NaN               NaN    140000.0
# Ecuador                     NaN        NaN          120000.0         NaN
# England                     NaN        NaN          478000.0         NaN
# France                 495000.0   145000.0          375000.0    459000.0
# ...

# %% [markdown]
# Создайте сводную таблицу, содержащую сведения о количестве игроков, занимающих разные позиции в каждом клубе. Отсутствующие значения замените нулями.
#
# Каково среднее количество вратарей (GK) в клубе? Ответ округлите до трёх цифр после запятой.

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Club'],
columns=['Position'],
aggfunc='count',
fill_value=0)
display(pivot)
# Out:
#                   Name                                                        \
# Position           CAM CB CDM CM GK LB LCB LCM LF LM LW RB RCB RCM RDM RF RM
# Club
# FC Barcelona         1  4   1  1  4  1   1   1  0  0  1  1   1   1   0  1  0
# Juventus             0  1   1  0  1  2   1   0  1  3  0  0   1   1   0  0  0
# Manchester United    0  5   1  2  2  2   0   0  0  0  2  0   1   0   1  0  1
# Real Madrid          0  1   2  1  3  2   0   2  0  0  1  1   2   1   0  0  0
#
#
# Position          RS RW ST
# Club
# FC Barcelona       1  2  0
# Juventus           0  0  2
# Manchester United  0  1  2
# Real Madrid        0  2  4

# %%
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Name', aggfunc = 'count',fill_value=0)
df2.mean()
# Out:
# Position
# CAM    0.973846
# CB     2.158462
# CDM    1.063077
# CF     0.078462
# CM     1.641538
# GK     2.524615
# LAM    0.009231
# LB     1.541538
# LCB    0.629231
# LCM    0.358462
# LDM    0.227692
# LF     0.012308
# LM     1.120000
# LS     0.186154
# LW     0.372308
# LWB    0.092308
# RAM    0.007692
# RB     1.458462
# RCB    0.643077
# RCM    0.369231
# RDM    0.212308
# RF     0.009231
# RM     1.178462
# RS     0.175385
# RW     0.364615
# RWB    0.107692
# ST     2.326154
# dtype: float64

# %% [markdown]
# Используя таблицу, созданную на предыдущем шаге, определите, сколько клубов не содержат данных о центральных полузащитниках. (CM)
#
# Подсказка: для выполнения этого задания желательно сохранить сводную таблицу в виде отдельного датафрейма и сгруппировать часть данных этого датафрейма с помощью value_counts().

# %%
df2['CM'].value_counts()
# Out:
# 1    211
# 2    149
# 0    136
# 3     89
# 4     39
# 5     21
# 6      5
# Name: CM, dtype: int64

# %% [markdown]
# С помощью сводной таблицы и функции loc посчитайте, сколько получают ("Wage") русские футболисты ("Russia"), играющие за ФК "AS Monaco".

# %%
pivot = df.loc[df['Club'].isin(['AS Monaco','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Club'],
columns=['Nationality'],
aggfunc='sum',
fill_value=0)
display(pivot)
# Out:
#                        Wage                                             \
# Nationality       Argentina Belgium Bosnia Herzegovina  Brazil   Chile
# Club
# AS Monaco                 0   47000                  0   55000       0
# Juventus             205000       0             180000  335000       0
# Manchester United    206000  230000                  0   91000  215000
# Real Madrid               0  240000                  0  570000       0
#
#                                                                           ...  \
# Nationality       Colombia Costa Rica Croatia Dominican Republic Ecuador  ...
# Club                                                                      ...
# AS Monaco           115000          0   70000                  0       0  ...
# Juventus                 0          0  160000                  0       0  ...
# Manchester United        0          0       0                  0  120000  ...
# ...

# %% [markdown]
# Cоздайте сводную таблицу, содержащую сведения о средней скорости футболистов, занимающих разные позиции (Position) в разных футбольных клубах (Club).
#
# Основываясь на данных таблицы, отметьте три позиции, представители которых в среднем обладают самой высокой скоростью.

# %%
df2 = df.loc[df['Club'].isin(['AS Monaco','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['SprintSpeed'],
index=['Club'],
columns=['Position'],
aggfunc='mean',
fill_value=0)
display(df2)
# Out:
#                   SprintSpeed                                                 \
# Position                  CAM    CB CDM    CM         GK    LB LCB   LCM  LF
# Club
# AS Monaco                  83  51.0  62  64.0  48.000000  64.0  65   0.0   0
# Juventus                    0  75.0  66   0.0  47.000000  76.5  75   0.0  83
# Manchester United           0  69.2  59  64.5  51.000000  72.5   0   0.0   0
# Real Madrid                 0  63.0  62  63.0  45.666667  80.5   0  64.5   0
#
#
# Position                  LM  LW  RB RCB RCM RDM  RM  RS    RW     ST
# Club
# AS Monaco           0.000000   0  79  52   0   0  76  66   0.0  78.50
# Juventus           84.333333   0   0  65  60   0   0   0   0.0  82.00
# Manchester United   0.000000  91   0  74   0  79  85   0  79.0  84.00
# Real Madrid         0.000000  69  79  80  72   0   0   0  80.5  80.25
